# %% [markdown]
# # Coding Challenge 1 : Looping & Modulo
#
# Minggu ini, challenge kita adalah melakukan looping dengan Python. Contoh looping :

# %% [markdown]
# ### **Soal 1**:
#
# Print out integers which are multiples of 3 from 1 to 22.
# (Print out bilangan bulat yang merupakan kelipatan 3 dari 1 sampai 22).
#
# **Ekspektasi jawaban:**
#
# Ketika kode kalian di-run, muncul angka-angka: 3, 6, 9, 12, 15, 18, 21. Gunakan looping.

# %%
for x in range (1,23):
  if x%3 == 0:
    print (f"{x} adalah kelipatan 3 dari 1 sampai 22")
  else:
    print (f"{x} bukan kelipatan 3 dari 1 sampai 22")
# Out:
# 1 bukan kelipatan 3 dari 1 sampai 22
# 2 bukan kelipatan 3 dari 1 sampai 22
# 3 adalah kelipatan 3 dari 1 sampai 22
# 4 bukan kelipatan 3 dari 1 sampai 22
# 5 bukan kelipatan 3 dari 1 sampai 22
# 6 adalah kelipatan 3 dari 1 sampai 22
# 7 bukan kelipatan 3 dari 1 sampai 22
# 8 bukan kelipatan 3 dari 1 sampai 22
# 9 adalah kelipatan 3 dari 1 sampai 22
# 10 bukan kelipatan 3 dari 1 sampai 22
# 11 bukan kelipatan 3 dari 1 sampai 22
# 12 adalah kelipatan 3 dari 1 sampai 22
# 13 bukan kelipatan 3 dari 1 sampai 22
# 14 bukan kelipatan 3 dari 1 sampai 22
# 15 adalah kelipatan 3 dari 1 sampai 22
# 16 bukan kelipatan 3 dari 1 sampai 22
# 17 bukan kelipatan 3 dari 1 sampai 22
# 18 adalah kelipatan 3 dari 1 sampai 22
# 19 bukan kelipatan 3 dari 1 sampai 22
# 20 bukan kelipatan 3 dari 1 sampai 22
# 21 adalah kelipatan 3 dari 1 sampai 22
# 22 bukan kelipatan 3 dari 1 sampai 22

# %% [markdown]
# ### **Soal 2**:
#
# Buat sebuah function di Python untuk mengecek apakah sebuah angka merupakan bilangan prima atau bukan.
#
# Ekspektasi jawaban:
#
# misal fungsi Anda bernama prime_check. Ketika kita jalankan prime_check(5), maka outputnya adalah '5 is a Prime number'. Fungsi ini harus bisa berlaku untuk input apa pun.
#
# Clue: Pengecekan bilangan prima menggunakan looping dan modulo.
# ```(python)
# print('Hasil dari 5 modulo 2 adalah',5 % 2)
# # 5 Modulo 2 sama dengan 1. Artinya, 5 dibagi 2, sisanya 1
#
# print('Hasil dari 6 modulo 3 adalah', 6 % 3)
# # 6 Modulo 3 sama dengan 0. Artinya 6 dibagi 3, sisanya 0.
# ```
#
# Selamat mengerjakan!

# %%
x = int(input('input angka: '))

angka_prima = True
if((x == 0) or (x == 1)): #yang pertama diselesaikan adalah kode ini
  angka_prima = False #yang ketiga diselesaikan adalah kode ini
else: #yang keempat diselesaikan adalah kode ini
  for i in range(2,(x//2)):
    if ((x % i) == 0): #yang kedua diselesaikan adalah kode ini
       angka_prima = False #yang terakhir diselesaikan adalah kode ini
       break

if(angka_prima):
  print(x,'adalah angka prima')
else:
  print(x,'bukan angka prima')
# Out:
# input angka: 186
# 186 bukan angka prima
